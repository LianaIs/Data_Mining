# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules, apriori
from collections import Counter

# %%
df = pd.read_csv("C:/Users/ASUS/Downloads/GroceryStoreDataSet.csv", names = ['products'], sep = ',')
df.head()
# Out:
#                         products
# 0             MILK,BREAD,BISCUIT
# 1  BREAD,MILK,BISCUIT,CORNFLAKES
# 2            BREAD,TEA,BOURNVITA
# 3           JAM,MAGGI,BREAD,MILK
# 4              MAGGI,TEA,BISCUIT

# %% [markdown]
# ### 1) Prepare the data to run apriori algorithm

# %%
data = [a.split(',') for a in df.products.values.tolist()]
data
# Out:
# [['MILK', 'BREAD', 'BISCUIT'],
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['JAM', 'MAGGI', 'BREAD', 'MILK'],
#  ['MAGGI', 'TEA', 'BISCUIT'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['MAGGI', 'TEA', 'CORNFLAKES'],
#  ['MAGGI', 'BREAD', 'TEA', 'BISCUIT'],
#  ['JAM', 'MAGGI', 'BREAD', 'TEA'],
#  ['BREAD', 'MILK'],
#  ['COFFEE', 'COCK', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'COCK', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'COCK'],
#  ['BREAD', 'SUGER', 'BISCUIT'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['TEA', 'MILK', 'COFFEE', 'CORNFLAKES']]

# %%
te = TransactionEncoder()
te_data = te.fit_transform(data)

display(te_data)
# Out:
# array([[ True, False,  True, False, False, False, False, False,  True,
#         False, False],
#        [ True, False,  True, False, False,  True, False, False,  True,
#         False, False],
#        [False,  True,  True, False, False, False, False, False, False,
#         False,  True],
#        [False, False,  True, False, False, False,  True,  True,  True,
#         False, False],
#        [ True, False, False, False, False, False, False,  True, False,
#         False,  True],
#        [False,  True,  True, False, False, False, False, False, False,
#         False,  True],
#        [False, False, False, False, False,  True, False,  True, False,
#         False,  True],
#        [ True, False,  True, False, False, False, False,  True, False,
#         False,  True],
#        [False, False,  True, False, False, False,  True,  True, False,
#         False,  True],
#        [False, False,  True, False, False, False, False, False,  True,
#         False, False],
#        [ True, False, False,  True,  True,  True, False, False, False,
#         False, False],
#        [ True, False, False,  True,  True,  True, False, False, False,
#         False, False],
#        [False,  True, False, False,  True, False, False, False, False,
#          True, False],
#        [False, False,  True,  True,  True, False, False, False, False,
#         False, False],
#        [ True, False,  True, False, False, False, False, False, False,
#          True, False],
#        [False, False, False, False,  True,  True, False, False, False,
#          True, False],
#        [False,  True,  True, False, False, False, False, False, False,
#          True, False],
#        [False, False,  True, False,  True, False, False, False, False,
#          True, False],
#        [False, False,  True, False,  True, False, False, False, False,
#          True, False],
#        [False, False, False, False,  True,  True, False, False,  True,
#         False,  True]])

# %%
data_x = pd.DataFrame(te_data,columns=te.columns_)

display(data_x.head())
# Out:
#    BISCUIT  BOURNVITA  BREAD   COCK  COFFEE  CORNFLAKES    JAM  MAGGI   MILK  \
# 0     True      False   True  False   False       False  False  False   True
# 1     True      False   True  False   False        True  False  False   True
# 2    False       True   True  False   False       False  False  False  False
# 3    False      False   True  False   False       False   True   True   True
# 4     True      False  False  False   False       False  False   True  False
#
#    SUGER    TEA
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False  False
# 4  False   True

# %% [markdown]
# ### 2) Select frequent itemsets with min support of 10%

# %%
frequent_items = apriori(data_x, use_colnames=True, min_support=0.1)
frequent_items
# Out:
#     support                             itemsets
# 0      0.35                            (BISCUIT)
# 1      0.20                          (BOURNVITA)
# 2      0.65                              (BREAD)
# 3      0.15                               (COCK)
# 4      0.40                             (COFFEE)
# 5      0.30                         (CORNFLAKES)
# 6      0.10                                (JAM)
# 7      0.25                              (MAGGI)
# 8      0.25                               (MILK)
# 9      0.30                              (SUGER)
# 10     0.35                                (TEA)
# 11     0.20                     (BREAD, BISCUIT)
# 12     0.10                      (COCK, BISCUIT)
# 13     0.10                    (BISCUIT, COFFEE)
# 14     0.15                (BISCUIT, CORNFLAKES)
# 15     0.10                     (MAGGI, BISCUIT)
# 16     0.10                      (BISCUIT, MILK)
# 17     0.10                       (TEA, BISCUIT)
# 18     0.15                   (BREAD, BOURNVITA)
# 19     0.10                   (BOURNVITA, SUGER)
# 20     0.10                     (TEA, BOURNVITA)
# 21     0.15                      (BREAD, COFFEE)
# 22     0.10                         (BREAD, JAM)
# 23     0.15                       (BREAD, MAGGI)
# 24     0.20                        (BREAD, MILK)
# 25     0.20                       (BREAD, SUGER)
# 26     0.20                         (TEA, BREAD)
# 27     0.15                       (COCK, COFFEE)
# 28     0.10                   (COCK, CORNFLAKES)
# 29     0.20                 (COFFEE, CORNFLAKES)
# 30     0.20                      (SUGER, COFFEE)
# 31     0.10                   (MILK, CORNFLAKES)
# 32     0.10                    (TEA, CORNFLAKES)
# 33     0.10                         (MAGGI, JAM)
# 34     0.20                         (TEA, MAGGI)
# 35     0.10               (BREAD, BISCUIT, MILK)
# 36     0.10              (COCK, BISCUIT, COFFEE)
# 37     0.10          (COCK, BISCUIT, CORNFLAKES)
# 38     0.10        (BISCUIT, COFFEE, CORNFLAKES)
# 39     0.10                (TEA, MAGGI, BISCUIT)
# 40     0.10              (TEA, BREAD, BOURNVITA)
# 41     0.10               (BREAD, SUGER, COFFEE)
# 42     0.10                  (BREAD, MAGGI, JAM)
# 43     0.10                  (TEA, BREAD, MAGGI)
# 44     0.10           (COCK, COFFEE, CORNFLAKES)
# 45     0.10  (COCK, BISCUIT, COFFEE, CORNFLAKES)

# %% [markdown]
# ### 3) Find out which item (not itemset) is the most frequent in the frequent itemset and how many times it appears

# %%
ones = [a for a in frequent_items.itemsets.values if len(a) == 1]
ones
# Out:
# [frozenset({'BISCUIT'}),
#  frozenset({'BOURNVITA'}),
#  frozenset({'BREAD'}),
#  frozenset({'COCK'}),
#  frozenset({'COFFEE'}),
#  frozenset({'CORNFLAKES'}),
#  frozenset({'JAM'}),
#  frozenset({'MAGGI'}),
#  frozenset({'MILK'}),
#  frozenset({'SUGER'}),
#  frozenset({'TEA'})]

# %%
new = frequent_items[frequent_items['itemsets'].isin(ones)]
new
# Out:
#     support      itemsets
# 0      0.35     (BISCUIT)
# 1      0.20   (BOURNVITA)
# 2      0.65       (BREAD)
# 3      0.15        (COCK)
# 4      0.40      (COFFEE)
# 5      0.30  (CORNFLAKES)
# 6      0.10         (JAM)
# 7      0.25       (MAGGI)
# 8      0.25        (MILK)
# 9      0.30       (SUGER)
# 10     0.35         (TEA)

# %% [markdown]
# #### As long as
#     Support = (Number of transaction in which X appears)/(Total number of transactions)

# %%
data = [new["itemsets"], new["support"] * 20] # 20 is the count of all combinations
headers = ["itemsets", "counts"]
final = pd.concat(data, axis=1, keys=headers)
final.sort_values('counts', ascending=False)
# Out:
#         itemsets  counts
# 2        (BREAD)    13.0
# 4       (COFFEE)     8.0
# 0      (BISCUIT)     7.0
# 10         (TEA)     7.0
# 5   (CORNFLAKES)     6.0
# 9        (SUGER)     6.0
# 7        (MAGGI)     5.0
# 8         (MILK)     5.0
# 1    (BOURNVITA)     4.0
# 3         (COCK)     3.0
# 6          (JAM)     2.0

# %% [markdown]
# So, the answer is BREAD

# %% [markdown]
# ### 4) Print association rules using already obtained frequent itemsets filtered by confidence above 70%

# %%
rules = association_rules(frequent_items, min_threshold=0.7)
rules
# Out:
#                       antecedents           consequents  antecedent support  \
# 0                     (BOURNVITA)               (BREAD)                0.20
# 1                           (JAM)               (BREAD)                0.10
# 2                          (MILK)               (BREAD)                0.25
# 3                          (COCK)              (COFFEE)                0.15
# 4                           (JAM)               (MAGGI)                0.10
# 5                         (MAGGI)                 (TEA)                0.25
# 6                 (BISCUIT, MILK)               (BREAD)                0.10
# 7                 (COCK, BISCUIT)              (COFFEE)                0.10
# 8               (BISCUIT, COFFEE)                (COCK)                0.10
# 9                 (COCK, BISCUIT)          (CORNFLAKES)                0.10
# 10             (COCK, CORNFLAKES)             (BISCUIT)                0.10
# 11              (BISCUIT, COFFEE)          (CORNFLAKES)                0.10
# 12                 (TEA, BISCUIT)               (MAGGI)                0.10
# 13               (MAGGI, BISCUIT)                 (TEA)                0.10
# 14               (TEA, BOURNVITA)               (BREAD)                0.10
# 15                   (BREAD, JAM)               (MAGGI)                0.10
# 16                   (MAGGI, JAM)               (BREAD)                0.10
# 17                          (JAM)        (BREAD, MAGGI)                0.10
# 18             (COCK, CORNFLAKES)              (COFFEE)                0.10
# 19        (COCK, BISCUIT, COFFEE)          (CORNFLAKES)                0.10
# 20    (COCK, BISCUIT, CORNFLAKES)              (COFFEE)                0.10
# 21     (COCK, COFFEE, CORNFLAKES)             (BISCUIT)                0.10
# 22  (BISCUIT, COFFEE, CORNFLAKES)                (COCK)                0.10
# 23                (COCK, BISCUIT)  (COFFEE, CORNFLAKES)                0.10
# 24             (COCK, CORNFLAKES)     (BISCUIT, COFFEE)                0.10
# 25              (BISCUIT, COFFEE)    (COCK, CORNFLAKES)                0.10
#
#     consequent support  support  confidence       lift  leverage  conviction
# 0                 0.65     0.15        0.75   1.153846    0.0200        1.40
# 1                 0.65     0.10        1.00   1.538462    0.0350         inf
# 2                 0.65     0.20        0.80   1.230769    0.0375        1.75
# 3                 0.40     0.15        1.00   2.500000    0.0900         inf
# 4                 0.25     0.10        1.00   4.000000    0.0750         inf
# 5                 0.35     0.20        0.80   2.285714    0.1125        3.25
# 6                 0.65     0.10        1.00   1.538462    0.0350         inf
# 7                 0.40     0.10        1.00   2.500000    0.0600         inf
# 8                 0.15     0.10        1.00   6.666667    0.0850         inf
# 9                 0.30     0.10        1.00   3.333333    0.0700         inf
# 10                0.35     0.10        1.00   2.857143    0.0650         inf
# 11                0.30     0.10        1.00   3.333333    0.0700         inf
# 12                0.25     0.10        1.00   4.000000    0.0750         inf
# 13                0.35     0.10        1.00   2.857143    0.0650         inf
# 14                0.65     0.10        1.00   1.538462    0.0350         inf
# 15                0.25     0.10        1.00   4.000000    0.0750         inf
# 16                0.65     0.10        1.00   1.538462    0.0350         inf
# 17                0.15     0.10        1.00   6.666667    0.0850         inf
# 18                0.40     0.10        1.00   2.500000    0.0600         inf
# 19                0.30     0.10        1.00   3.333333    0.0700         inf
# 20                0.40     0.10        1.00   2.500000    0.0600         inf
# 21                0.35     0.10        1.00   2.857143    0.0650         inf
# 22                0.15     0.10        1.00   6.666667    0.0850         inf
# 23                0.20     0.10        1.00   5.000000    0.0800         inf
# 24                0.10     0.10        1.00  10.000000    0.0900         inf
# 25                0.10     0.10        1.00  10.000000    0.0900         inf

# %% [markdown]
# ### 5) Print the rule that has lowest confidence

# %%
rules[rules.confidence==min(rules.confidence)]
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0  (BOURNVITA)     (BREAD)                 0.2                0.65     0.15
#
#    confidence      lift  leverage  conviction
# 0        0.75  1.153846      0.02         1.4

# %% [markdown]
# ### 6) Print the rules which has values lift > 3 and consequent support > 20

# %%
rules[(rules.lift>3) & (rules['consequent support']>=0.2)]
# Out:
#                 antecedents           consequents  antecedent support  \
# 4                     (JAM)               (MAGGI)                 0.1
# 9           (COCK, BISCUIT)          (CORNFLAKES)                 0.1
# 11        (BISCUIT, COFFEE)          (CORNFLAKES)                 0.1
# 12           (TEA, BISCUIT)               (MAGGI)                 0.1
# 15             (BREAD, JAM)               (MAGGI)                 0.1
# 19  (COCK, BISCUIT, COFFEE)          (CORNFLAKES)                 0.1
# 23          (COCK, BISCUIT)  (COFFEE, CORNFLAKES)                 0.1
#
#     consequent support  support  confidence      lift  leverage  conviction
# 4                 0.25      0.1         1.0  4.000000     0.075         inf
# 9                 0.30      0.1         1.0  3.333333     0.070         inf
# 11                0.30      0.1         1.0  3.333333     0.070         inf
# 12                0.25      0.1         1.0  4.000000     0.075         inf
# 15                0.25      0.1         1.0  4.000000     0.075         inf
# 19                0.30      0.1         1.0  3.333333     0.070         inf
# 23                0.20      0.1         1.0  5.000000     0.080         inf

# %% [markdown]
# ### 7) Print the rules which antecedents itemset contains coffee

# %%
rules[rules['antecedents'].astype(str).str.lower().str.contains('coffee')]
# Out:
#                       antecedents         consequents  antecedent support  \
# 8               (BISCUIT, COFFEE)              (COCK)                 0.1
# 11              (BISCUIT, COFFEE)        (CORNFLAKES)                 0.1
# 19        (COCK, BISCUIT, COFFEE)        (CORNFLAKES)                 0.1
# 21     (COCK, COFFEE, CORNFLAKES)           (BISCUIT)                 0.1
# 22  (BISCUIT, COFFEE, CORNFLAKES)              (COCK)                 0.1
# 25              (BISCUIT, COFFEE)  (COCK, CORNFLAKES)                 0.1
#
#     consequent support  support  confidence       lift  leverage  conviction
# 8                 0.15      0.1         1.0   6.666667     0.085         inf
# 11                0.30      0.1         1.0   3.333333     0.070         inf
# 19                0.30      0.1         1.0   3.333333     0.070         inf
# 21                0.35      0.1         1.0   2.857143     0.065         inf
# 22                0.15      0.1         1.0   6.666667     0.085         inf
# 25                0.10      0.1         1.0  10.000000     0.090         inf

# %% [markdown]
# ### 8) Please write down your suggestions for the business based on the results that you have. State as well the metrics, which helped you to construct your suggestions.

# %% [markdown]
# * Bread is the bestseller item in this shop (it appears 13 times in 20 purcahses). Cofee is the second (8 from 20).
# * Bread has a assosiation rule with the folloging items and itemsents: BOURNVITA, JAM, MILK, (BISCUIT, MILK), (TEA, BOURNVITA), (MAGGI, JAM) - see appendix 1.
# * MAGGI and CORNFLAKES are the best assotiated ones with other items and itemsets (based on lift and consequent support). This means they should always be srounded by the other items for better sales.
# * Coffe shows association with cock, cornflakes and biscuit. Placing these items close to coffee ordering counter can be a good strategy to attract customers in buying these.
# * The lowest assotiation (probability to be bought with other items) based on confidence value has BOURNVITA. Still, it's associated with bread sales (lift>1). The shop should either try to promote it with discounts to have the assotions with bread as well, or just to stop to sell this product.

# %% [markdown]
# #### Appendix 1. Some helping queries.

# %%
rules[(rules.lift>1)]
# Out:
#                       antecedents           consequents  antecedent support  \
# 0                     (BOURNVITA)               (BREAD)                0.20
# 1                           (JAM)               (BREAD)                0.10
# 2                          (MILK)               (BREAD)                0.25
# 3                          (COCK)              (COFFEE)                0.15
# 4                           (JAM)               (MAGGI)                0.10
# 5                         (MAGGI)                 (TEA)                0.25
# 6                 (BISCUIT, MILK)               (BREAD)                0.10
# 7                 (COCK, BISCUIT)              (COFFEE)                0.10
# 8               (BISCUIT, COFFEE)                (COCK)                0.10
# 9                 (COCK, BISCUIT)          (CORNFLAKES)                0.10
# 10             (COCK, CORNFLAKES)             (BISCUIT)                0.10
# 11              (BISCUIT, COFFEE)          (CORNFLAKES)                0.10
# 12                 (TEA, BISCUIT)               (MAGGI)                0.10
# 13               (MAGGI, BISCUIT)                 (TEA)                0.10
# 14               (TEA, BOURNVITA)               (BREAD)                0.10
# 15                   (BREAD, JAM)               (MAGGI)                0.10
# 16                   (MAGGI, JAM)               (BREAD)                0.10
# 17                          (JAM)        (BREAD, MAGGI)                0.10
# 18             (COCK, CORNFLAKES)              (COFFEE)                0.10
# 19        (COCK, BISCUIT, COFFEE)          (CORNFLAKES)                0.10
# 20    (COCK, BISCUIT, CORNFLAKES)              (COFFEE)                0.10
# 21     (COCK, COFFEE, CORNFLAKES)             (BISCUIT)                0.10
# 22  (BISCUIT, COFFEE, CORNFLAKES)                (COCK)                0.10
# 23                (COCK, BISCUIT)  (COFFEE, CORNFLAKES)                0.10
# 24             (COCK, CORNFLAKES)     (BISCUIT, COFFEE)                0.10
# 25              (BISCUIT, COFFEE)    (COCK, CORNFLAKES)                0.10
#
#     consequent support  support  confidence       lift  leverage  conviction
# 0                 0.65     0.15        0.75   1.153846    0.0200        1.40
# 1                 0.65     0.10        1.00   1.538462    0.0350         inf
# 2                 0.65     0.20        0.80   1.230769    0.0375        1.75
# 3                 0.40     0.15        1.00   2.500000    0.0900         inf
# 4                 0.25     0.10        1.00   4.000000    0.0750         inf
# 5                 0.35     0.20        0.80   2.285714    0.1125        3.25
# 6                 0.65     0.10        1.00   1.538462    0.0350         inf
# 7                 0.40     0.10        1.00   2.500000    0.0600         inf
# 8                 0.15     0.10        1.00   6.666667    0.0850         inf
# 9                 0.30     0.10        1.00   3.333333    0.0700         inf
# 10                0.35     0.10        1.00   2.857143    0.0650         inf
# 11                0.30     0.10        1.00   3.333333    0.0700         inf
# 12                0.25     0.10        1.00   4.000000    0.0750         inf
# 13                0.35     0.10        1.00   2.857143    0.0650         inf
# 14                0.65     0.10        1.00   1.538462    0.0350         inf
# 15                0.25     0.10        1.00   4.000000    0.0750         inf
# 16                0.65     0.10        1.00   1.538462    0.0350         inf
# 17                0.15     0.10        1.00   6.666667    0.0850         inf
# 18                0.40     0.10        1.00   2.500000    0.0600         inf
# 19                0.30     0.10        1.00   3.333333    0.0700         inf
# 20                0.40     0.10        1.00   2.500000    0.0600         inf
# 21                0.35     0.10        1.00   2.857143    0.0650         inf
# 22                0.15     0.10        1.00   6.666667    0.0850         inf
# 23                0.20     0.10        1.00   5.000000    0.0800         inf
# 24                0.10     0.10        1.00  10.000000    0.0900         inf
# 25                0.10     0.10        1.00  10.000000    0.0900         inf

# %% [markdown]
# **Lift** – Overcoming the limitation of confidence measure, Lift will calculate the confidence taking into account the popularity of both items. Representation of lift in mathematical terms is:
#
# Lift({X} => {Y}) = Confidence({X} => {Y}) / Support(Y)
#
# If the lift measure is greater than 1, it means that the Y is likely to be bought with X, while a value less than 1 indicates that Y is unlikely to be bought with X. A lift value of near 1 indicates that both the itemsets in the transactions are appearing often together but there is no association between them.
